# %% [markdown]
# # Coverage of ISIC sectors (high level) by EX sectors and EI activities
# based on bridge matrix and ecoinvent ISIC classfications

# %%
import pandas as pd
import pickle
from itertools import islice

pd.options.display.float_format = '{:.3g}'.format

# %% [markdown]
# # Load data

# %%
scenario = '2019-12-02_WW'  # must be the same as the HIOT Excel sheetname

# %%
DATA_PATH = "../data/"
SCENARIO_PATH = "../results/" + scenario + "/"
print(SCENARIO_PATH)
# Out:
# ../results/2019-12-02_WW/

# %%
def load_pickle(filename):
    with open(filename, 'rb') as handle:
        data = pickle.load(handle)
        print(len(data))
        if isinstance(data, dict):
            print(list(islice(data.items(), 2)))
    return data

# %% [markdown]
# ### File names

# %%
# ecoinvent
activity_overview = f"{DATA_PATH}ecoinvent/activity_overview_3.4_cut-off_LCIA_results.xlsx"

# EXIOBASE
hiot_results = f"{DATA_PATH}exiobase/hiot_results_PTM_v2.xlsx"
hiot_results_sheet = scenario  #"v_3_3_18_2019-11-22"

# Matching file
matching_file = f"{DATA_PATH}matching/Matching file.xlsx"
# Sheets
product_matching_sheet = 'product matching'
process_matching_sheet = 'process matching electricity'
region_matching_sheet = "regional matching"

# Matching
#product_matching = f"{DATA_PATH}matching/match_v4.xlsx"
#product_matching_sheet = 'concordance'
#process_matching = f"{DATA_PATH}matching/match_v2_electricity.xlsx"
#region_matching = f"{DATA_PATH}matching/matching_ecoinvent_Exiobase_geographies.xlsx"
#region_matching_sheet = "matched_191117"

# %% [markdown]
# # ISIC classifications

# %% [markdown]
# ### ISIC file
# This file includes isic classifications level 1-4 plus additionally level 5 classifications from ecoinvent

# %%
ISIC = pd.read_excel(f"{DATA_PATH}matching/ISIC.xlsx", sheet_name="ISIC4")
print(ISIC.shape)
ISIC.head(2)
# Out:
# (783, 18)
#   Code                                        Description  Level 1  Level 2  \
# 0    A                  Agriculture, forestry and fishing        1        0
# 1   01  Crop and animal production, hunting and relate...        0        1
#
#    Level 3  Level 4  Level 5 Top category Code 1  Code 2 Code 3 Code 4 Code 5  \
# 0        0        0        0            A      A     NaN    NaN    NaN    NaN
# 1        0        0        0            A      A       1    NaN    NaN    NaN
#
#                        Description 1  \
# 0  Agriculture, forestry and fishing
# 1  Agriculture, forestry and fishing
#
#                                        Description 2 Description 3  \
# 0                                                NaN           NaN
# 1  Crop and animal production, hunting and relate...           NaN
#
#   Description 4 Description 5
# 0           NaN           NaN
# 1           NaN           NaN

# %%
def get_ISIC_levelX(description, level=1, debug=False):
    """Return a higher or lower level ISIC names and codes, if possible."""
    lookup_columns = ['Description 1', 'Description 2', 'Description 3', 'Description 4', 'Description 5']
    result = None
    
    for col in lookup_columns:
        # print(col)
        if description in ISIC[col].tolist():
            indices = ISIC[col].index[ISIC[col] == description].tolist()
            output_level = 'Description ' + str(level)
            result = set(ISIC.iloc[indices][output_level].tolist())
            if debug:
                print('Found in', col)
                print('Indices:', ISIC[col].index[ISIC[col] == description].tolist())
                print('Level', level, 'match:', result)
       
    return result

# %%
d5 = ' Liquid and gaseous fuels from biomass'
d3 = 'Growing of non-perennial crops'
d2 = 'Crop and animal production, hunting and related service activities'
d = 'Agriculture, forestry and fishing'
get_ISIC_levelX(d5, level=2, debug=True)
# Out:
# Found in Description 5
# Indices: [162]
# Level 2 match: {'Manufacture of coke and refined petroleum products'}
# {'Manufacture of coke and refined petroleum products'}

# %% [markdown]
# # Results template (ISIC level 1)

# %%
DF = ISIC[['Code', 'Description']].loc[ISIC['Level 1'] == 1]
DF.reset_index(inplace=True, drop=True)
DF
# Out:
#    Code                                        Description
# 0     A                  Agriculture, forestry and fishing
# 1     B                               Mining and quarrying
# 2     C                                      Manufacturing
# 3     D  Electricity, gas, steam and air conditioning s...
# 4     E  Water supply; sewerage, waste management and r...
# 5     F                                       Construction
# 6     G  Wholesale and retail trade; repair of motor ve...
# 7     H                         Transportation and storage
# 8     I          Accommodation and food service activities
# 9     J                      Information and communication
# 10    K                 Financial and insurance activities
# 11    L                             Real estate activities
# 12    M  Professional, scientific and technical activities
# 13    N      Administrative and support service activities
# 14    O  Public administration and defence; compulsory ...
# 15    P                                          Education
# 16    Q            Human health and social work activities
# 17    R                 Arts, entertainment and recreation
# 18    S                           Other service activities
# 19    T  Activities of households as employers; undiffe...
# 20    U  Activities of extraterritorial organizations a...

# %% [markdown]
# # Ecoinvent

# %% [markdown]
# ### ecoinvent activity overview

# %%
AO = pd.read_excel(f"{DATA_PATH}ecoinvent/activity_overview_3.4_cut-off_LCIA_results_with_ISIC_details.xlsx")
print(AO.shape)
AO = AO[AO['specialActivityType'] == 'ordinary transforming activity']
print(AO.shape)
AO.head(2)
# Out:
# (14889, 57)
# (10805, 57)
#    Unnamed: 0                                                key     #  \
# 0           0  ('ecoinvent 3.4 cutoff', '60274947cf82e6633d8c...  2607
# 1           1  ('ecoinvent 3.4 cutoff', '7dd298333a92144698cf...  5307
#
#                                      id  \
# 0  2d83c1a0-0c9b-4589-bb9b-6a81e815f5e2
# 1  59913008-58ba-4f1a-8bf2-86925bbd6005
#
#                                             filename  \
# 0  2d83c1a0-0c9b-4589-bb9b-6a81e815f5e2_4c2b1cc3-...
# 1  59913008-58ba-4f1a-8bf2-86925bbd6005_4c2b1cc3-...
#
#                          activityName geography   startDate     endDate  \
# 0  [sulfonyl]urea-compound production       RER  2000-01-01  2017-12-31
# 1  [sulfonyl]urea-compound production       RoW  2000-01-01  2017-12-31
#
#               specialActivityType  ...  Description 1  \
# 0  ordinary transforming activity  ...  Manufacturing
# 1  ordinary transforming activity  ...  Manufacturing
#
#                                     Description 2  \
# 0  Manufacture of chemicals and chemical products
# 1  Manufacture of chemicals and chemical products
#
#                             Description 3  \
# 0  Manufacture of other chemical products
# 1  Manufacture of other chemical products
#
#                                        Description 4 Description 5  \
# 0  Manufacture of pesticides and other agrochemic...           NaN
# 1  Manufacture of pesticides and other agrochemic...           NaN
#
#             ISIC 1                                             ISIC 2  \
# 0  C:Manufacturing  20:Manufacture of chemicals and chemical products
# 1  C:Manufacturing  20:Manufacture of chemicals and chemical products
#
#                                        ISIC 3  \
# 0  202:Manufacture of other chemical products
# 1  202:Manufacture of other chemical products
#
#                                               ISIC 4  ISIC 5
# 0  2021:Manufacture of pesticides and other agroc...     NaN
# 1  2021:Manufacture of pesticides and other agroc...     NaN
#
# [2 rows x 57 columns]

# %%
AOnRoW = AO[AO['geography'] != 'RoW']
AOnRoW.shape
# Out:
# (7986, 57)

# %%
# number of unique products
print(len(AO.name.unique()))
print(len(AOnRoW.name.unique()))
# Out:
# 2851
# 2851

# %%
# number of unique product-activity combinations (what we describe in the paper as "products")
print(len((AO.name+"//"+AO.activityName).unique()))
print(len((AOnRoW.name+AOnRoW.activityName).unique()))
# Out:
# 4208
# 4150

# %%
#These 58 activities have ONLY a RoW representation (didn't know that this exists in ecoinvent...)
set((AO.name+"//"+AO.activityName).unique()) - set((AOnRoW.name+"//"+AOnRoW.activityName).unique())
# Out:
# {'electricity, for reuse in municipal waste incineration only//treatment of liquid crystal display, municipal waste incineration',
#  'electricity, for reuse in municipal waste incineration only//treatment of raw sewage sludge, municipal incineration',
#  'electricity, for reuse in municipal waste incineration only//treatment of residue from mechanical treatment, IT accessory, municipal waste incineration',
#  'electricity, for reuse in municipal waste incineration only//treatment of residue from mechanical treatment, cathode ray tube display, municipal waste incineration',
#  'electricity, for reuse in municipal waste incineration only//treatment of residue from mechanical treatment, desktop computer, municipal waste incineration',
#  'electricity, for reuse in municipal waste incineration only//treatment of residue from mechanical treatment, industrial device, municipal waste incineration',
#  'electricity, for reuse in municipal waste incineration only//treatment of residue from mechanical treatment, laptop computer, municipal waste incineration',
#  'electricity, for reuse in municipal waste incineration only//treatment of residue from mechanical treatment, laser printer, municipal waste incineration',
#  'electricity, for reuse in municipal waste incineration only//treatment of residue from mechanical treatment, liquid crystal display, municipal waste incineration',
#  'electricity, for reuse in municipal waste incineration only//treatment of residue from shredder fraction from manual dismantling, municipal waste incineration',
#  'electricity, for reuse in municipal waste incineration only//treatment of spent anion exchange resin from potable water production, municipal incineration',
#  'electricity, for reuse in municipal waste incineration only//treatment of waste bitumen sheet, municipal incineration',
#  'electricity, for reuse in municipal waste incineration only//treatment of waste building wood, chrome preserved, municipal incineration',
#  'electricity, for reuse in municipal waste incineration only//treatment of waste cement-fibre slab, municipal incineration',
#  'electricity, for reuse in municipal waste incineration only//treatment of waste expanded polystyrene, municipal incineration',
#  'electricity, for reuse in municipal waste incineration only//treatment of waste newspaper, municipal incineration',
#  'electricity, for reuse in municipal waste incineration only//treatment of waste packaging paper, municipal incineration',
#  'electricity, for reuse in municipal waste incineration only//treatment of waste plastic, consumer electronics, municipal incineration',
#  'electricity, for reuse in municipal waste incineration only//treatment of waste plastic, industrial electronics, municipal incineration',
#  'electricity, for reuse in municipal waste incineration only//treatment of waste polypropylene, municipal incineration',
#  'electricity, for reuse in municipal waste incineration only//treatment of waste polyvinylfluoride, municipal incineration',
#  'electricity, for reuse in municipal waste incineration only//treatment of waste sealing sheet, polyethylene, municipal incineration',
#  'electricity, for reuse in municipal waste incineration only//treatment of waste sealing sheet, polyvinylchloride, municipal incineration',
#  'electricity, for reuse in municipal waste incineration only//treatment of waste textile, soiled, municipal incineration',
#  'electricity, for reuse in municipal waste incineration only//treatment of waste vapour barrier, flame-retarded, municipal incineration',
#  'electricity, for reuse in municipal waste incineration only//treatment of waste wire plastic, municipal incineration',
#  'electricity, for reuse in municipal waste incineration only//treatment of waste wood pole, chrome preserved, municipal incineration',
#  'electricity, for reuse in municipal waste incineration only//treatment of waste wood, untreated, municipal incineration',
#  'heat, for reuse in municipal waste incineration only//treatment of liquid crystal display, municipal waste incineration',
#  'heat, for reuse in municipal waste incineration only//treatment of raw sewage sludge, municipal incineration',
#  'heat, for reuse in municipal waste incineration only//treatment of residue from mechanical treatment, IT accessory, municipal waste incineration',
#  'heat, for reuse in municipal waste incineration only//treatment of residue from mechanical treatment, cathode ray tube display, municipal waste incineration',
#  'heat, for reuse in municipal waste incineration only//treatment of residue from mechanical treatment, desktop computer, municipal waste incineration',
#  'heat, for reuse in municipal waste incineration only//treatment of residue from mechanical treatment, industrial device, municipal waste incineration',
#  'heat, for reuse in municipal waste incineration only//treatment of residue from mechanical treatment, laptop computer, municipal waste incineration',
#  'heat, for reuse in municipal waste incineration only//treatment of residue from mechanical treatment, laser printer, municipal waste incineration',
#  'heat, for reuse in municipal waste incineration only//treatment of residue from mechanical treatment, liquid crystal display, municipal waste incineration',
#  'heat, for reuse in municipal waste incineration only//treatment of residue from shredder fraction from manual dismantling, municipal waste incineration',
#  'heat, for reuse in municipal waste incineration only//treatment of spent anion exchange resin from potable water production, municipal incineration',
#  'heat, for reuse in municipal waste incineration only//treatment of spent cation exchange resin from potable water production, municipal incineration',
#  'heat, for reuse in municipal waste incineration only//treatment of waste bitumen sheet, municipal incineration',
#  'heat, for reuse in municipal waste incineration only//treatment of waste building wood, chrome preserved, municipal incineration',
#  'heat, for reuse in municipal waste incineration only//treatment of waste cement-fibre slab, municipal incineration',
#  'heat, for reuse in municipal waste incineration only//treatment of waste expanded polystyrene, municipal incineration',
#  'heat, for reuse in municipal waste incineration only//treatment of waste newspaper, municipal incineration',
#  'heat, for reuse in municipal waste incineration only//treatment of waste packaging paper, municipal incineration',
#  'heat, for reuse in municipal waste incineration only//treatment of waste plastic, consumer electronics, municipal incineration',
#  'heat, for reuse in municipal waste incineration only//treatment of waste plastic, industrial electronics, municipal incineration',
#  'heat, for reuse in municipal waste incineration only//treatment of waste polypropylene, municipal incineration',
#  'heat, for reuse in municipal waste incineration only//treatment of waste polyvinylfluoride, municipal incineration',
#  'heat, for reuse in municipal waste incineration only//treatment of waste sealing sheet, polyethylene, municipal incineration',
#  'heat, for reuse in municipal waste incineration only//treatment of waste sealing sheet, polyvinylchloride, municipal incineration',
#  'heat, for reuse in municipal waste incineration only//treatment of waste textile, soiled, municipal incineration',
#  'heat, for reuse in municipal waste incineration only//treatment of waste vapour barrier, flame-retarded, municipal incineration',
#  'heat, for reuse in municipal waste incineration only//treatment of waste wire plastic, municipal incineration',
#  'heat, for reuse in municipal waste incineration only//treatment of waste wood pole, chrome preserved, municipal incineration',
#  'heat, for reuse in municipal waste incineration only//treatment of waste wood, untreated, municipal incineration',
#  'indium rich leaching residues, from zinc production//primary zinc production from concentrate'}

# %%
# number of unique product-activity-geography combinations
print(len((AO.name+AO.activityName+AO.geography).unique()))
print(len((AOnRoW.name+AOnRoW.activityName+AOnRoW.geography).unique()))
# Out:
# 10803
# 7984

# %%
diff = pd.concat([AO, AOnRoW]).drop_duplicates(keep=False)
diff
# Out:
#        Unnamed: 0                                                key      #  \
# 1               1  ('ecoinvent 3.4 cutoff', '7dd298333a92144698cf...   5307
# 3               3  ('ecoinvent 3.4 cutoff', '35e16ca3f2007a0186f0...   7754
# 5               5  ('ecoinvent 3.4 cutoff', '555a1f49dfd1dd13e5a2...   5781
# 7               7  ('ecoinvent 3.4 cutoff', '49aa7ecf75011a9cdbac...  12231
# 9               9  ('ecoinvent 3.4 cutoff', '14406fd5b1ec4fbe5112...   8992
# ...           ...                                                ...    ...
# 14861       14861  ('ecoinvent 3.4 cutoff', '06c94c3c4da6e53b4873...  14264
# 14863       14863  ('ecoinvent 3.4 cutoff', '861c0a3ea73ad63e000d...   2288
# 14878       14878  ('ecoinvent 3.4 cutoff', 'b2511a5336e78b9c1829...   9199
# 14884       14884  ('ecoinvent 3.4 cutoff', 'e657c56e8e73a80ce50a...   8257
# 14888       14888  ('ecoinvent 3.4 cutoff', 'a1336aabee4520d84b2a...   8539
#
#                                          id  \
# 1      59913008-58ba-4f1a-8bf2-86925bbd6005
# 3      8419276e-31ac-4859-b9ce-05d4f05199c6
# 5      61ee25d4-accb-4d44-b381-9b78e0f057d5
# 7      d1b0e57c-90c3-49c1-b6e3-19e5e162a569
# 9      99d608c8-6d0e-4ee6-96aa-783e2a30690f
# ...                                     ...
# 14861  f52990d1-7b30-4be6-8af7-719934c01f70
# 14863  27f369f3-985d-4146-a3e3-07a008c7a38c
# 14878  9d5f632b-2d29-45ba-9eaa-136ab4ac75b3
# 14884  8cc16b95-47c4-487c-9277-b534d40f8bdb
# 14888  91de71ca-0823-4aed-911b-1d4fd4251148
#
#                                                 filename  \
# 1      59913008-58ba-4f1a-8bf2-86925bbd6005_4c2b1cc3-...
# 3      8419276e-31ac-4859-b9ce-05d4f05199c6_1be4f7e4-...
# 5      61ee25d4-accb-4d44-b381-9b78e0f057d5_2487d46f-...
# 7      d1b0e57c-90c3-49c1-b6e3-19e5e162a569_906ace6c-...
# 9      99d608c8-6d0e-4ee6-96aa-783e2a30690f_bc06c7e3-...
# ...                                                  ...
# 14861  f52990d1-7b30-4be6-8af7-719934c01f70_a90c974c-...
# 14863  27f369f3-985d-4146-a3e3-07a008c7a38c_dd0af955-...
# 14878  9d5f632b-2d29-45ba-9eaa-136ab4ac75b3_8578a99c-...
# 14884  8cc16b95-47c4-487c-9277-b534d40f8bdb_5d4272ad-...
# 14888  91de71ca-0823-4aed-911b-1d4fd4251148_5d4272ad-...
#
#                                             activityName geography  \
# 1                     [sulfonyl]urea-compound production       RoW
# 3                    [thio]carbamate-compound production       RoW
# 5      acetamide-anillide-compound production, unspec...       RoW
# 7                                   aclonifen production       RoW
# 9                                    atrazine production       RoW
# ...                                                  ...       ...
# 14861             tube insulation production, elastomere       RoW
# 14863                    uranium hexafluoride production       RoW
# 14878          power sawing, without catalytic converter       RoW
# 14884                         transport, passenger train       RoW
# 14888             transport, passenger train, high-speed       RoW
#
#         startDate     endDate             specialActivityType  ...  \
# 1      2000-01-01  2017-12-31  ordinary transforming activity  ...
# 3      2000-01-01  2017-12-31  ordinary transforming activity  ...
# 5      2000-01-01  2017-12-31  ordinary transforming activity  ...
# 7      2000-01-01  2017-12-31  ordinary transforming activity  ...
# 9      2000-01-01  2017-12-31  ordinary transforming activity  ...
# ...           ...         ...                             ...  ...
# 14861  1997-01-01  2017-12-31  ordinary transforming activity  ...
# 14863  1982-01-01  2017-12-31  ordinary transforming activity  ...
# 14878  2011-01-01  2017-12-31  ordinary transforming activity  ...
# 14884  2000-01-01  2017-12-31  ordinary transforming activity  ...
# 14888  2000-01-01  2017-12-31  ordinary transforming activity  ...
#
#                            Description 1  \
# 1                          Manufacturing
# 3                          Manufacturing
# 5                          Manufacturing
# 7                          Manufacturing
# 9                          Manufacturing
# ...                                  ...
# 14861                      Manufacturing
# 14863                      Manufacturing
# 14878  Agriculture, forestry and fishing
# 14884         Transportation and storage
# 14888         Transportation and storage
#
#                                         Description 2  \
# 1      Manufacture of chemicals and chemical products
# 3      Manufacture of chemicals and chemical products
# 5      Manufacture of chemicals and chemical products
# 7      Manufacture of chemicals and chemical products
# 9      Manufacture of chemicals and chemical products
# ...                                               ...
# 14861     Manufacture of rubber and plastics products
# 14863                     Manufacture of basic metals
# 14878                            Forestry and logging
# 14884      Land transport and transport via pipelines
# 14888      Land transport and transport via pipelines
#
#                                            Description 3  \
# 1                 Manufacture of other chemical products
# 3                 Manufacture of other chemical products
# 5                 Manufacture of other chemical products
# 7                 Manufacture of other chemical products
# 9                 Manufacture of other chemical products
# ...                                                  ...
# 14861                     Manufacture of rubber products
# 14863  Manufacture of basic precious and other non-fe...
# 14878         Silviculture and other forestry activities
# 14884                             Transport via railways
# 14888                             Transport via railways
#
#                                            Description 4  \
# 1      Manufacture of pesticides and other agrochemic...
# 3      Manufacture of pesticides and other agrochemic...
# 5      Manufacture of pesticides and other agrochemic...
# 7      Manufacture of pesticides and other agrochemic...
# 9      Manufacture of pesticides and other agrochemic...
# ...                                                  ...
# 14861               Manufacture of other rubber products
# 14863  Manufacture of basic precious and other non-fe...
# 14878         Silviculture and other forestry activities
# 14884               Passenger rail transport, interurban
# 14888               Passenger rail transport, interurban
#
#                            Description 5                               ISIC 1  \
# 1                                    NaN                      C:Manufacturing
# 3                                    NaN                      C:Manufacturing
# 5                                    NaN                      C:Manufacturing
# 7                                    NaN                      C:Manufacturing
# 9                                    NaN                      C:Manufacturing
# ...                                  ...                                  ...
# 14861                                NaN                      C:Manufacturing
# 14863   Smelting and refining of uranium                      C:Manufacturing
# 14878                                NaN  A:Agriculture, forestry and fishing
# 14884                                NaN         H:Transportation and storage
# 14888                                NaN         H:Transportation and storage
#
#                                                   ISIC 2  \
# 1      20:Manufacture of chemicals and chemical products
# 3      20:Manufacture of chemicals and chemical products
# 5      20:Manufacture of chemicals and chemical products
# 7      20:Manufacture of chemicals and chemical products
# 9      20:Manufacture of chemicals and chemical products
# ...                                                  ...
# 14861     22:Manufacture of rubber and plastics products
# 14863                     24:Manufacture of basic metals
# 14878                            02:Forestry and logging
# 14884      49:Land transport and transport via pipelines
# 14888      49:Land transport and transport via pipelines
#
#                                                   ISIC 3  \
# 1             202:Manufacture of other chemical products
# 3             202:Manufacture of other chemical products
# 5             202:Manufacture of other chemical products
# 7             202:Manufacture of other chemical products
# 9             202:Manufacture of other chemical products
# ...                                                  ...
# 14861                 221:Manufacture of rubber products
# 14863  242:Manufacture of basic precious and other no...
# 14878     021:Silviculture and other forestry activities
# 14884                         491:Transport via railways
# 14888                         491:Transport via railways
#
#                                                   ISIC 4  \
# 1      2021:Manufacture of pesticides and other agroc...
# 3      2021:Manufacture of pesticides and other agroc...
# 5      2021:Manufacture of pesticides and other agroc...
# 7      2021:Manufacture of pesticides and other agroc...
# 9      2021:Manufacture of pesticides and other agroc...
# ...                                                  ...
# 14861          2219:Manufacture of other rubber products
# 14863  2420:Manufacture of basic precious and other n...
# 14878    0210:Silviculture and other forestry activities
# 14884          4911:Passenger rail transport, interurban
# 14888          4911:Passenger rail transport, interurban
#
#                                         ISIC 5
# 1                                          NaN
# 3                                          NaN
# 5                                          NaN
# 7                                          NaN
# 9                                          NaN
# ...                                        ...
# 14861                                      NaN
# 14863  2420a: Smelting and refining of uranium
# 14878                                      NaN
# 14884                                      NaN
# 14888                                      NaN
#
# [2819 rows x 57 columns]

# %%
EI_ISIC = AO['key'].groupby(AO['Description 1']).count()
EI_ISIC.name = 'ecoinvent, w/o markets'
#EI_ISIC = EI_ISIC.astype(int)
EI_ISIC
# Out:
# Description 1
# Administrative and support service activities                             85
# Agriculture, forestry and fishing                                        808
# Construction                                                             525
# Electricity, gas, steam and air conditioning supply                     3162
# Information and communication                                             13
# Manufacturing                                                           3907
# Mining and quarrying                                                     284
# Other service activities                                                   2
# Professional, scientific and technical activities                          4
# Real estate activities                                                   200
# Transportation and storage                                               248
# Water supply; sewerage, waste management and remediation activities     1504
# Wholesale and retail trade; repair of motor vehicles and motorcycles      18
# Name: ecoinvent, w/o markets, dtype: int64

# %%
print('Activities in ecoinvent that have an ISIC classification:', EI_ISIC.sum())
print('Activities that lack and ISIC classification:', AO.shape[0] - EI_ISIC.sum())
# these are "electricity ... production mixes" and "Recycled Content cut-off" activities
# Out:
# Activities in ecoinvent that have an ISIC classification: 10760
# Activities that lack and ISIC classification: 45

# %%
DF_EI = DF.join(EI_ISIC, 'Description').fillna(value=0).astype({'ecoinvent, w/o markets': int})
DF_EI
# Out:
#    Code                                        Description  \
# 0     A                  Agriculture, forestry and fishing
# 1     B                               Mining and quarrying
# 2     C                                      Manufacturing
# 3     D  Electricity, gas, steam and air conditioning s...
# 4     E  Water supply; sewerage, waste management and r...
# 5     F                                       Construction
# 6     G  Wholesale and retail trade; repair of motor ve...
# 7     H                         Transportation and storage
# 8     I          Accommodation and food service activities
# 9     J                      Information and communication
# 10    K                 Financial and insurance activities
# 11    L                             Real estate activities
# 12    M  Professional, scientific and technical activities
# 13    N      Administrative and support service activities
# 14    O  Public administration and defence; compulsory ...
# 15    P                                          Education
# 16    Q            Human health and social work activities
# 17    R                 Arts, entertainment and recreation
# 18    S                           Other service activities
# 19    T  Activities of households as employers; undiffe...
# 20    U  Activities of extraterritorial organizations a...
#
#     ecoinvent, w/o markets
# 0                      808
# 1                      284
# 2                     3907
# 3                     3162
# 4                     1504
# 5                      525
# 6                       18
# 7                      248
# 8                        0
# 9                       13
# 10                       0
# 11                     200
# 12                       4
# 13                      85
# 14                       0
# 15                       0
# 16                       0
# 17                       0
# 18                       2
# 19                       0
# 20                       0

# %% [markdown]
# ### Ecoinvent "reduced"

# %% [markdown]
# 1. only "ordinary transforming activities", i.e. no markets, production mixes, market groups
# 2. only unique product-activity combinations, i.e. ignoring p-a combinations that occur in several geographies

# %% [markdown]
# #### Group by product and activity to "drop" the geographies

# %%
AOng = AO.groupby(['name', 'activityName', 'Description 1']).count()
#AOng = AOt.groupby(['name', 'activityName']).count()
#AOng = AOt.groupby(['activityName', 'name',]).count()
AOng.reset_index(inplace=True)  
print(AOng.shape)
AOng
# Out:
# (4164, 57)
#                               name                             activityName  \
# 0     1,1-difluoroethane, HFC-152a  1,1-difluoroethane production, HFC-152a
# 1         1,1-dimethylcyclopentane    molecular sieve separation of naphtha
# 2                        1-butanol            hydroformylation of propylene
# 3                       1-pentanol               hydroformylation of butene
# 4                       1-propanol                    1-propanol production
# ...                            ...                                      ...
# 4159                    zinc oxide                    zinc oxide production
# 4160                  zinc sulfide                  zinc sulfide production
# 4161         zircon, 50% zirconium      heavy mineral sand quarry operation
# 4162               zirconium oxide               zirconium oxide production
# 4163                      zucchini                      zucchini production
#
#                           Description 1  Unnamed: 0  key  #  id  filename  \
# 0                         Manufacturing           2    2  2   2         2
# 1                         Manufacturing           2    2  2   2         2
# 2                         Manufacturing           2    2  2   2         2
# 3                         Manufacturing           2    2  2   2         2
# 4                         Manufacturing           2    2  2   2         2
# ...                                 ...         ...  ... ..  ..       ...
# 4159                      Manufacturing           2    2  2   2         2
# 4160                      Manufacturing           2    2  2   2         2
# 4161               Mining and quarrying           2    2  2   2         2
# 4162                      Manufacturing           2    2  2   2         2
# 4163  Agriculture, forestry and fishing           1    1  1   1         1
#
#       geography  startDate  ...  Code 5  Description 2  Description 3  \
# 0             2          2  ...       0              2              2
# 1             2          2  ...       0              2              2
# 2             2          2  ...       0              2              2
# 3             2          2  ...       0              2              2
# 4             2          2  ...       0              2              2
# ...         ...        ...  ...     ...            ...            ...
# 4159          2          2  ...       0              2              2
# 4160          2          2  ...       0              2              2
# 4161          2          2  ...       0              2              2
# 4162          2          2  ...       0              2              2
# 4163          1          1  ...       0              1              1
#
#       Description 4  Description 5  ISIC 1  ISIC 2  ISIC 3  ISIC 4  ISIC 5
# 0                 2              0       2       2       2       2       0
# 1                 2              0       2       2       2       2       0
# 2                 2              0       2       2       2       2       0
# 3                 2              0       2       2       2       2       0
# 4                 2              0       2       2       2       2       0
# ...             ...            ...     ...     ...     ...     ...     ...
# 4159              2              0       2       2       2       2       0
# 4160              2              0       2       2       2       2       0
# 4161              2              0       2       2       2       2       0
# 4162              2              0       2       2       2       2       0
# 4163              1              0       1       1       1       1       0
#
# [4164 rows x 57 columns]

# %%
EIng = AOng['Description 1'].groupby(AOng['Description 1']).count()
EIng.name = 'ecoinvent, w/o markets and geographies'
print(EIng.sum())
EIng
# Out:
# 4164
# Description 1
# Administrative and support service activities                             26
# Agriculture, forestry and fishing                                        398
# Construction                                                             279
# Electricity, gas, steam and air conditioning supply                      343
# Information and communication                                              6
# Manufacturing                                                           2059
# Mining and quarrying                                                     135
# Other service activities                                                   1
# Professional, scientific and technical activities                          2
# Real estate activities                                                    13
# Transportation and storage                                               151
# Water supply; sewerage, waste management and remediation activities      741
# Wholesale and retail trade; repair of motor vehicles and motorcycles      10
# Name: ecoinvent, w/o markets and geographies, dtype: int64

# %% [markdown]
# #### Join with results DF

# %%
DF_EIr = DF_EI.join(EIng, 'Description').fillna(value=0).astype({'ecoinvent, w/o markets and geographies': int})
DF_EIr.to_clipboard()
DF_EIr
# Out:
#    Code                                        Description  \
# 0     A                  Agriculture, forestry and fishing
# 1     B                               Mining and quarrying
# 2     C                                      Manufacturing
# 3     D  Electricity, gas, steam and air conditioning s...
# 4     E  Water supply; sewerage, waste management and r...
# 5     F                                       Construction
# 6     G  Wholesale and retail trade; repair of motor ve...
# 7     H                         Transportation and storage
# 8     I          Accommodation and food service activities
# 9     J                      Information and communication
# 10    K                 Financial and insurance activities
# 11    L                             Real estate activities
# 12    M  Professional, scientific and technical activities
# 13    N      Administrative and support service activities
# 14    O  Public administration and defence; compulsory ...
# 15    P                                          Education
# 16    Q            Human health and social work activities
# 17    R                 Arts, entertainment and recreation
# 18    S                           Other service activities
# 19    T  Activities of households as employers; undiffe...
# 20    U  Activities of extraterritorial organizations a...
#
#     ecoinvent, w/o markets  ecoinvent, w/o markets and geographies
# 0                      808                                     398
# 1                      284                                     135
# 2                     3907                                    2059
# 3                     3162                                     343
# 4                     1504                                     741
# 5                      525                                     279
# 6                       18                                      10
# 7                      248                                     151
# 8                        0                                       0
# 9                       13                                       6
# 10                       0                                       0
# 11                     200                                      13
# 12                       4                                       2
# 13                      85                                      26
# 14                       0                                       0
# 15                       0                                       0
# 16                       0                                       0
# 17                       0                                       0
# 18                       2                                       1
# 19                       0                                       0
# 20                       0                                       0

# %% [markdown]
# # EXIOBASE

# %% [markdown]
# ### Load manually matched HIOT sectors to ISIC Code1

# %%
HIOT_ISIC = pd.read_excel(f"{DATA_PATH}matching/ISIC.xlsx", sheet_name="exiobase")
HIOT_ISIC.rename(columns={"ISIC Code 1": "Code"}, inplace=True)
HIOT_ISIC.head()
# Out:
#    # Code                 ProductTypeName_of_hiot product code 1  \
# 0  1    A               Cultivation of paddy rice          c01.a
# 1  2    A                    Cultivation of wheat          c01.b
# 2  3    A        Cultivation of cereal grains nec          c01.c
# 3  4    A  Cultivation of vegetables, fruit, nuts          c01.d
# 4  5    A                Cultivation of oil seeds          c01.e
#
#   product code 2
# 0         P_PARI
# 1         P_WHEA
# 2         P_OCER
# 3         P_FVEG
# 4         P_OILS

# %%
HIOT_nonregionalized = HIOT_ISIC.groupby('Code')['#'].nunique()
HIOT_nonregionalized
# Out:
# Code
# A    19
# B    15
# C    48
# D    17
# E    35
# F     1
# G     4
# H     7
# I     1
# J     1
# K     3
# L     2
# M     2
# N     1
# O     1
# P     1
# Q     1
# R     1
# S     2
# T     1
# U     1
# Name: #, dtype: int64

# %% [markdown]
# ### Instead of multiplying by 48, get actual numbers of sectors (not always fully regionalized) from "hiot_results.xlsx"

# %%
HIOT = pd.read_excel(hiot_results, sheet_name=hiot_results_sheet)
print(HIOT.shape)
HIOT
# Out:
# (8200, 10)
#          # CountryCode                            ProductTypeName_of_hiot  \
# 0        1          AU                          Cultivation of paddy rice
# 1        2          AU                               Cultivation of wheat
# 2        3          AU                   Cultivation of cereal grains nec
# 3        4          AU             Cultivation of vegetables, fruit, nuts
# 4        5          AU                           Cultivation of oil seeds
# ...    ...         ...                                                ...
# 8195  8196       EU-28  Activities of membership organisation n.e.c. (91)
# 8196  8197       EU-28  Recreational, cultural and sporting activities...
# 8197  8198       EU-28                      Other service activities (93)
# 8198  8199       EU-28      Private households with employed persons (95)
# 8199  8200       EU-28         Extra-territorial organizations and bodies
#
#      product code 1 product code 2 OriginalPhysicalUnit  GHGs-eq - tonnes  \
# 0             c01.a         P_PARI               tonnes               1.6
# 1             c01.b         P_WHEA               tonnes             0.307
# 2             c01.c         P_OCER               tonnes             0.266
# 3             c01.d         P_FVEG               tonnes             0.724
# 4             c01.e         P_OILS               tonnes             0.395
# ...             ...            ...                  ...               ...
# 8195            c91         P_ORGA                Meuro               294
# 8196            c92         P_RECR                Meuro               206
# 8197            c93         P_OSER                Meuro               158
# 8198            c95         P_PRHH                Meuro               108
# 8199            c99         P_EXTO                Meuro                 0
#
#      PhysicalUnit  CarbonFootprint             unit
# 0              kg              1.6     kg CO2-eq/kg
# 1              kg            0.307     kg CO2-eq/kg
# 2              kg            0.266     kg CO2-eq/kg
# 3              kg            0.724     kg CO2-eq/kg
# 4              kg            0.395     kg CO2-eq/kg
# ...           ...              ...              ...
# 8195        Meuro              294  kg CO2-eq/Meuro
# 8196        Meuro              206  kg CO2-eq/Meuro
# 8197        Meuro              158  kg CO2-eq/Meuro
# 8198        Meuro              108  kg CO2-eq/Meuro
# 8199        Meuro                0  kg CO2-eq/Meuro
#
# [8200 rows x 10 columns]

# %% [markdown]
# #### Exclude GLO, EU-28 and rows where GWP=0 (products not produced in a country)

# %%
HIOTr = HIOT[HIOT['CountryCode'] != 'GLO']
HIOTr = HIOTr[HIOTr['CountryCode'] != 'EU-28']
print(HIOTr.shape)
HIOTr = HIOTr[HIOTr['CarbonFootprint'] != 0]
print(HIOTr.shape)
# Out:
# (7872, 10)
# (6692, 10)

# %% [markdown]
# #### Merge with ISIC code 1

# %%
HIOTm = pd.merge(HIOTr, HIOT_ISIC[['ProductTypeName_of_hiot','Code']], on=["ProductTypeName_of_hiot"], how="inner")
print(HIOTm.shape)
HIOTm.head()
# Out:
# (6692, 11)
#       # CountryCode    ProductTypeName_of_hiot product code 1 product code 2  \
# 0     1          AU  Cultivation of paddy rice          c01.a         P_PARI
# 1   493          BR  Cultivation of paddy rice          c01.a         P_PARI
# 2   657          BG  Cultivation of paddy rice          c01.a         P_PARI
# 3   985          CN  Cultivation of paddy rice          c01.a         P_PARI
# 4  1969          FR  Cultivation of paddy rice          c01.a         P_PARI
#
#   OriginalPhysicalUnit  GHGs-eq - tonnes PhysicalUnit  CarbonFootprint  \
# 0               tonnes               1.6           kg              1.6
# 1               tonnes             0.697           kg            0.697
# 2               tonnes              0.43           kg             0.43
# 3               tonnes              2.02           kg             2.02
# 4               tonnes              0.31           kg             0.31
#
#            unit Code
# 0  kg CO2-eq/kg    A
# 1  kg CO2-eq/kg    A
# 2  kg CO2-eq/kg    A
# 3  kg CO2-eq/kg    A
# 4  kg CO2-eq/kg    A

# %%
HIOT_regionalized = HIOTm.groupby('Code')['#'].nunique()
HIOT_regionalized
# Out:
# Code
# A     761
# B     437
# C    2185
# D     572
# E    1347
# F      48
# G     192
# H     336
# I      48
# J      48
# K     144
# L      96
# M      96
# N      48
# O      48
# P      48
# Q      48
# R      48
# S      96
# T      46
# Name: #, dtype: int64

# %% [markdown]
# ## Merge ecoinvent and EXIOBASE data

# %%
HIOT_nonregionalized
# Out:
# Code
# A    19
# B    15
# C    48
# D    17
# E    35
# F     1
# G     4
# H     7
# I     1
# J     1
# K     3
# L     2
# M     2
# N     1
# O     1
# P     1
# Q     1
# R     1
# S     2
# T     1
# U     1
# Name: #, dtype: int64

# %%
DF = pd.merge(DF_EIr, HIOT_nonregionalized, on=["Code"], how="outer").fillna(value=0)
DF.rename(columns={"#": "EXIOBASE, non-regionalized"}, inplace=True)
DF = pd.merge(DF, HIOT_regionalized, on=["Code"], how="outer").fillna(value=0)
DF.rename(columns={"#": "EXIOBASE"}, inplace=True)
DF
# Out:
#    Code                                        Description  \
# 0     A                  Agriculture, forestry and fishing
# 1     B                               Mining and quarrying
# 2     C                                      Manufacturing
# 3     D  Electricity, gas, steam and air conditioning s...
# 4     E  Water supply; sewerage, waste management and r...
# 5     F                                       Construction
# 6     G  Wholesale and retail trade; repair of motor ve...
# 7     H                         Transportation and storage
# 8     I          Accommodation and food service activities
# 9     J                      Information and communication
# 10    K                 Financial and insurance activities
# 11    L                             Real estate activities
# 12    M  Professional, scientific and technical activities
# 13    N      Administrative and support service activities
# 14    O  Public administration and defence; compulsory ...
# 15    P                                          Education
# 16    Q            Human health and social work activities
# 17    R                 Arts, entertainment and recreation
# 18    S                           Other service activities
# 19    T  Activities of households as employers; undiffe...
# 20    U  Activities of extraterritorial organizations a...
#
#     ecoinvent, w/o markets  ecoinvent, w/o markets and geographies  \
# 0                      808                                     398
# 1                      284                                     135
# 2                     3907                                    2059
# 3                     3162                                     343
# 4                     1504                                     741
# 5                      525                                     279
# 6                       18                                      10
# 7                      248                                     151
# 8                        0                                       0
# 9                       13                                       6
# 10                       0                                       0
# 11                     200                                      13
# 12                       4                                       2
# 13                      85                                      26
# 14                       0                                       0
# 15                       0                                       0
# 16                       0                                       0
# 17                       0                                       0
# 18                       2                                       1
# 19                       0                                       0
# 20                       0                                       0
#
#     EXIOBASE, non-regionalized  EXIOBASE
# 0                           19       761
# 1                           15       437
# 2                           48  2.18e+03
# 3                           17       572
# 4                           35  1.35e+03
# 5                            1        48
# 6                            4       192
# 7                            7       336
# 8                            1        48
# 9                            1        48
# 10                           3       144
# 11                           2        96
# 12                           2        96
# 13                           1        48
# 14                           1        48
# 15                           1        48
# 16                           1        48
# 17                           1        48
# 18                           2        96
# 19                           1        46
# 20                           1         0

# %% [markdown]
# # Present data

# %% [markdown]
# #### Ratios

# %%
DF['Ratio, non-regionalized'] = DF['ecoinvent, w/o markets and geographies']/DF['EXIOBASE, non-regionalized']
DF['Ratio'] = DF['ecoinvent, w/o markets']/DF['EXIOBASE']
DF
# Out:
#    Code                                        Description  \
# 0     A                  Agriculture, forestry and fishing
# 1     B                               Mining and quarrying
# 2     C                                      Manufacturing
# 3     D  Electricity, gas, steam and air conditioning s...
# 4     E  Water supply; sewerage, waste management and r...
# 5     F                                       Construction
# 6     G  Wholesale and retail trade; repair of motor ve...
# 7     H                         Transportation and storage
# 8     I          Accommodation and food service activities
# 9     J                      Information and communication
# 10    K                 Financial and insurance activities
# 11    L                             Real estate activities
# 12    M  Professional, scientific and technical activities
# 13    N      Administrative and support service activities
# 14    O  Public administration and defence; compulsory ...
# 15    P                                          Education
# 16    Q            Human health and social work activities
# 17    R                 Arts, entertainment and recreation
# 18    S                           Other service activities
# 19    T  Activities of households as employers; undiffe...
# 20    U  Activities of extraterritorial organizations a...
#
#     ecoinvent, w/o markets  ecoinvent, w/o markets and geographies  \
# 0                      808                                     398
# 1                      284                                     135
# 2                     3907                                    2059
# 3                     3162                                     343
# 4                     1504                                     741
# 5                      525                                     279
# 6                       18                                      10
# 7                      248                                     151
# 8                        0                                       0
# 9                       13                                       6
# 10                       0                                       0
# 11                     200                                      13
# 12                       4                                       2
# 13                      85                                      26
# 14                       0                                       0
# 15                       0                                       0
# 16                       0                                       0
# 17                       0                                       0
# 18                       2                                       1
# 19                       0                                       0
# 20                       0                                       0
#
#     EXIOBASE, non-regionalized  EXIOBASE  Ratio, non-regionalized  Ratio
# 0                           19       761                     20.9   1.06
# 1                           15       437                        9   0.65
# 2                           48  2.18e+03                     42.9   1.79
# 3                           17       572                     20.2   5.53
# 4                           35  1.35e+03                     21.2   1.12
# 5                            1        48                      279   10.9
# 6                            4       192                      2.5 0.0938
# 7                            7       336                     21.6  0.738
# 8                            1        48                        0      0
# 9                            1        48                        6  0.271
# 10                           3       144                        0      0
# 11                           2        96                      6.5   2.08
# 12                           2        96                        1 0.0417
# 13                           1        48                       26   1.77
# 14                           1        48                        0      0
# 15                           1        48                        0      0
# 16                           1        48                        0      0
# 17                           1        48                        0      0
# 18                           2        96                      0.5 0.0208
# 19                           1        46                        0      0
# 20                           1         0                        0    NaN

# %% [markdown]
# #### Column naming

# %%
column_names = [
"Code",
"Description",
"ecoinvent, w/o markets and geographies",
"EXIOBASE, non-regionalized",
"Ratio, non-regionalized",
"ecoinvent, w/o markets",
"EXIOBASE",
"Ratio",
]

# %%
DF = DF[column_names]
DF
# Out:
#    Code                                        Description  \
# 0     A                  Agriculture, forestry and fishing
# 1     B                               Mining and quarrying
# 2     C                                      Manufacturing
# 3     D  Electricity, gas, steam and air conditioning s...
# 4     E  Water supply; sewerage, waste management and r...
# 5     F                                       Construction
# 6     G  Wholesale and retail trade; repair of motor ve...
# 7     H                         Transportation and storage
# 8     I          Accommodation and food service activities
# 9     J                      Information and communication
# 10    K                 Financial and insurance activities
# 11    L                             Real estate activities
# 12    M  Professional, scientific and technical activities
# 13    N      Administrative and support service activities
# 14    O  Public administration and defence; compulsory ...
# 15    P                                          Education
# 16    Q            Human health and social work activities
# 17    R                 Arts, entertainment and recreation
# 18    S                           Other service activities
# 19    T  Activities of households as employers; undiffe...
# 20    U  Activities of extraterritorial organizations a...
#
#     ecoinvent, w/o markets and geographies  EXIOBASE, non-regionalized  \
# 0                                      398                          19
# 1                                      135                          15
# 2                                     2059                          48
# 3                                      343                          17
# 4                                      741                          35
# 5                                      279                           1
# 6                                       10                           4
# 7                                      151                           7
# 8                                        0                           1
# 9                                        6                           1
# 10                                       0                           3
# 11                                      13                           2
# 12                                       2                           2
# 13                                      26                           1
# 14                                       0                           1
# 15                                       0                           1
# 16                                       0                           1
# 17                                       0                           1
# 18                                       1                           2
# 19                                       0                           1
# 20                                       0                           1
#
#     Ratio, non-regionalized  ecoinvent, w/o markets  EXIOBASE  Ratio
# 0                      20.9                     808       761   1.06
# 1                         9                     284       437   0.65
# 2                      42.9                    3907  2.18e+03   1.79
# 3                      20.2                    3162       572   5.53
# 4                      21.2                    1504  1.35e+03   1.12
# 5                       279                     525        48   10.9
# 6                       2.5                      18       192 0.0938
# 7                      21.6                     248       336  0.738
# 8                         0                       0        48      0
# 9                         6                      13        48  0.271
# 10                        0                       0       144      0
# 11                      6.5                     200        96   2.08
# 12                        1                       4        96 0.0417
# 13                       26                      85        48   1.77
# 14                        0                       0        48      0
# 15                        0                       0        48      0
# 16                        0                       0        48      0
# 17                        0                       0        48      0
# 18                      0.5                       2        96 0.0208
# 19                        0                       0        46      0
# 20                        0                       0         0    NaN

# %% [markdown]
# #### Totals

# %%
DF_FINAL = DF.append(DF.sum(numeric_only=True), ignore_index=True)
DF_FINAL.to_clipboard()
DF_FINAL
# Out:
#    Code                                        Description  \
# 0     A                  Agriculture, forestry and fishing
# 1     B                               Mining and quarrying
# 2     C                                      Manufacturing
# 3     D  Electricity, gas, steam and air conditioning s...
# 4     E  Water supply; sewerage, waste management and r...
# 5     F                                       Construction
# 6     G  Wholesale and retail trade; repair of motor ve...
# 7     H                         Transportation and storage
# 8     I          Accommodation and food service activities
# 9     J                      Information and communication
# 10    K                 Financial and insurance activities
# 11    L                             Real estate activities
# 12    M  Professional, scientific and technical activities
# 13    N      Administrative and support service activities
# 14    O  Public administration and defence; compulsory ...
# 15    P                                          Education
# 16    Q            Human health and social work activities
# 17    R                 Arts, entertainment and recreation
# 18    S                           Other service activities
# 19    T  Activities of households as employers; undiffe...
# 20    U  Activities of extraterritorial organizations a...
# 21  NaN                                                NaN
#
#     ecoinvent, w/o markets and geographies  EXIOBASE, non-regionalized  \
# 0                                      398                          19
# 1                                      135                          15
# 2                                 2.06e+03                          48
# 3                                      343                          17
# 4                                      741                          35
# 5                                      279                           1
# 6                                       10                           4
# 7                                      151                           7
# 8                                        0                           1
# 9                                        6                           1
# 10                                       0                           3
# 11                                      13                           2
# 12                                       2                           2
# 13                                      26                           1
# 14                                       0                           1
# 15                                       0                           1
# 16                                       0                           1
# 17                                       0                           1
# 18                                       1                           2
# 19                                       0                           1
# 20                                       0                           1
# 21                                4.16e+03                         164
#
#     Ratio, non-regionalized  ecoinvent, w/o markets  EXIOBASE  Ratio
# 0                      20.9                     808       761   1.06
# 1                         9                     284       437   0.65
# 2                      42.9                3.91e+03  2.18e+03   1.79
# 3                      20.2                3.16e+03       572   5.53
# 4                      21.2                 1.5e+03  1.35e+03   1.12
# 5                       279                     525        48   10.9
# 6                       2.5                      18       192 0.0938
# 7                      21.6                     248       336  0.738
# 8                         0                       0        48      0
# 9                         6                      13        48  0.271
# 10                        0                       0       144      0
# 11                      6.5                     200        96   2.08
# 12                        1                       4        96 0.0417
# 13                       26                      85        48   1.77
# 14                        0                       0        48      0
# 15                        0                       0        48      0
# 16                        0                       0        48      0
# 17                        0                       0        48      0
# 18                      0.5                       2        96 0.0208
# 19                        0                       0        46      0
# 20                        0                       0         0    NaN
# 21                      457                1.08e+04  6.69e+03   26.1
